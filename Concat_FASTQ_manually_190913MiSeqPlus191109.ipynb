# %% [markdown]
# This script speciffies which files FASTQ files should be concatenated into the a single fastq file per sample / read direction.
#
# This  for the MiSeq completed on 190913.
# These are in the bloom_lab (and Mollie's) directory at:
#
# 190913_M03100_0478_000000000-CKT45
#
#
# PLUS the MiSeq completed on 191108 (dealt with on the 9th) that resequenced the same library (pooled at different ratios).
# This is in the bloom_lab (and Mollie's) directory at:
#
# 191101_M04866_0301_000000000-CMLDD
# all fastq files are labeled with "1B"
#
#
#
# Note that I must sort the R1 and R2 samples such that they are in the same order (and will remained match to eahc other) when concatenating multiple files.

# %%
import os
import glob
import re
import subprocess

# %%
fastqdir = './FASTQ_files/'
if not os.path.isdir(fastqdir):
    os.mkdir(fastqdir)
os.chdir(fastqdir)

# %%
# !pwd
# Out:
# /fh/fast/bloom_j/computational_notebooks/adingens/2019/SuperRes_Hypermut/FASTQ_files

# %%
sample_directs = {}

# %%
sample_directs["A3C-1"] = ["/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/A3C-1_S4_L001_R1_001.fastq.gz",
                           "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/A3C-1b_S4_L001_R1_001.fastq.gz"]


sample_directs["A3C-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/A3C-2_S15_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/A3C-2b_S15_L001_R1_001.fastq.gz"]

sample_directs["A3CE68A-1"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/A3CE68A-1_S5_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/A3CE68A-1b_S5_L001_R1_001.fastq.gz"]

sample_directs["A3CE68A-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/A3CE68A-2_S16_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/A3CE68A-2b_S16_L001_R1_001.fastq.gz"]

sample_directs["A3G-1"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/A3G-1_S3_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/A3G-1b_S3_L001_R1_001.fastq.gz"]

sample_directs["A3G-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/A3G-2_S14_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/A3G-2b_S14_L001_R1_001.fastq.gz"]

sample_directs["COII-1"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/COII-1_S11_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/COII-1b_S11_L001_R1_001.fastq.gz"]

sample_directs["COII-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/COII-2_S22_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/COII-2b_S22_L001_R1_001.fastq.gz"]

sample_directs["COIIE68AE254A-1"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/COIIE68AE254A-1_S12_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/COIIE68AE254A-1b_S12_L001_R1_001.fastq.gz"]

sample_directs["COIIE68AE254A-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/COIIE68AE254A-2_S23_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/COIIE68AE254A-2b_S23_L001_R1_001.fastq.gz"]

sample_directs["COTD-1"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/COTD-1_S6_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/COTD-1b_S6_L001_R1_001.fastq.gz"]

sample_directs["COTD-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/COTD-2_S17_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/COTD-2b_S17_L001_R1_001.fastq.gz"]

sample_directs["COTDE68AE254A-1"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/COTDE68AE254A-1_S8_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/COTDE68AE254A-1b_S8_L001_R1_001.fastq.gz"]

sample_directs["COTDE68AE254A-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/COTDE68AE254A-2_S19_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/COTDE68AE254A-2b_S19_L001_R1_001.fastq.gz"]

sample_directs["COTDE254A-1"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/COTDE254A-1_S7_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/COTDE254A-1b_S7_L001_R1_001.fastq.gz"]

sample_directs["COTDE254A-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/COTDE254A-2_S18_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/COTDE254A-2b_S18_L001_R1_001.fastq.gz"]

sample_directs["I188-1"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/I188-1_S9_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/I188-1b_S9_L001_R1_001.fastq.gz"]

sample_directs["I188-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/I188-2_S20_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/I188-2b_S20_L001_R1_001.fastq.gz"]

sample_directs["I188E68A-1"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/I188E68A-1_S10_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/I188E68A-1b_S10_L001_R1_001.fastq.gz"]

sample_directs["I188E68A-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/I188E68A-2_S21_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/I188E68A-2b_S21_L001_R1_001.fastq.gz"]

sample_directs["NoA3-1"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/NoA3-1_S2_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/NoA3-1b_S2_L001_R1_001.fastq.gz"]

sample_directs["NoA3-2"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/NoA3-2_S13_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/NoA3-2b_S13_L001_R1_001.fastq.gz"]

sample_directs["PLASMIDCTRL"] = [
    "/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/PLASMIDCTRL_S1_L001_R1_001.fastq.gz",
    "/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/PLASMIDCTRL-b_S1_L001_R1_001.fastq.gz"]

# %%
# !pwd
# Out:
# /fh/fast/bloom_j/computational_notebooks/adingens/2019/SuperRes_Hypermut/FASTQ_files

# %%
#iterate through samples 
for key in sample_directs:
    #dirlist = sample_directs[key]
    print("\n*********************")
    print ("\n parsing {0} files:".format(key))
    r1files = sample_directs[key]
    r2files = [w.replace('_R1_001.fastq.gz', '_R2_001.fastq.gz') for w in r1files]
    #r1files =[]
    #r2files = []
    #for direct in dirlist:
        
        #print("looking in {0}".format(direct))
        #dirr1files = glob.glob('{0}*R1*.fastq.gz'.format(direct))
        #for f in dirr1files:
        #    r1files.append(f)
        #dirr2files = glob.glob('{0}*R2*.fastq.gz'.format(direct))
        #for f2 in dirr2files:
        #    r2files.append(f2)
        
    assert len(r1files) == len(r2files)
    r1files.sort()
    r2files.sort()
    catf = '{0}_R1.fastq.gz'.format(key)
    if os.path.isfile(catf):
        print("\nConcatenated FASTQ file {0} already exists.".format(catf))
        print("\nFor this script, {0} would have been made by concatenating:\n\t{1}".format(
                catf, '\n\t'.join(r1files)))
    else:
        print("\n!!!!! \nCreating {0} by concatenating:\n\t{1}".format(
                catf, '\n\t'.join(r1files)))
        subprocess.check_call('zcat {0} | gzip > {1}'.format(
                ' '.join(r1files), catf), shell=True)
#now, do the same for R2 files
    catf2 = '{0}_R2.fastq.gz'.format(key)
    if os.path.isfile(catf2):
        print("\nConcatenated FASTQ file {0} already exists.".format(catf2))
        print("\nFor this script, {0} would have been made by concatenating:\n\t{1}".format(
                catf2, '\n\t'.join(r2files)))
    else:
        print("\nCreating {0} by concatenating:\n\t{1}".format(
                catf2, '\n\t'.join(r2files)))
        subprocess.check_call('zcat {0} | gzip > {1}'.format(
                ' '.join(r2files), catf2), shell=True)
# Out:
# *********************
#
#  parsing A3C-1 files:
#
# Concatenated FASTQ file A3C-1_R1.fastq.gz already exists.
#
# For this script, A3C-1_R1.fastq.gz would have been made by concatenating:
# 	/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/A3C-1_S4_L001_R1_001.fastq.gz
# 	/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/A3C-1b_S4_L001_R1_001.fastq.gz
#
# Concatenated FASTQ file A3C-1_R2.fastq.gz already exists.
#
# For this script, A3C-1_R2.fastq.gz would have been made by concatenating:
# 	/shared/ngs/illumina/bloom_lab/190913_M03100_0478_000000000-CKT45/Data/Intensities/BaseCalls/A3C-1_S4_L001_R2_001.fastq.gz
# 	/shared/ngs/illumina/bloom_lab/191101_M04866_0301_000000000-CMLDD/Data/Intensities/BaseCalls/A3C-1b_S4_L001_R2_001.fastq.gz
#
# *********************
#
#  parsing A3C-2 files:
#
# Concatenated FASTQ file A3C-2_R1.fastq.gz already exists.
#
# ...
